# %% [markdown]
# ## Python with machine learning Module 1
#
# ### Python
# - **Python programming language is a high level,object oriented programming language**
# - In 2026 Python is among mostly used programming language
#
# ## Why Python?
#  - It is simple as simple as english language
#  - It has large library
#  - It is object oriented programming language
#
#  ## What we are doing ?
#  - basics of python programming like loops, conditional, control, variables
#  - List Types in python list, tuple, dictionarycepyional handling
#  - Object oriented programming
#  - Exceptional handling
#  - File handling
#  - Machine Learning
#  - Supervised machine learning
#   - regression
#   - Classification
# - Web deploy (Djangol Flask)
#
# ## Job Role in Python
# - Web developer (flask, djnago,fastApi)
# - Security
# - Machine learning
# - Deep learning
# - Web scarping
# - Autoscripting
# - deployment (Docker, kubernetis, kafka) .yml(python)

# %%
print("Hello World")
# Out:
# Hello World

# %%
# int a=10; strongly typed programming language (C  C++ Java C#)  a=10 print

a=10 
b=10.20
print(a)
print(type(a))

print(b)
print (type(b))

name = "Pemba"
print(name)

print(a,b,name, sep=',')
# Out:
# 10
# <class 'int'>
# 10.2
# <class 'float'>
# Pemba
# 10,10.2,Pemba
